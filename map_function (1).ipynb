# %% [markdown]
# Reading: [Python: map()](https://aaweg-i.medium.com/python-functions-map-8bc457342d6b)

# %%
#Mapping Values Using a Dictionary:

import pandas as pd
data = {'A':['apple','banana','cherry','apple']}
df=pd.DataFrame(data)
fruit_to_color= {'apple':'red', 'banana':'yellow', 'cherry':'red'}
df['color']=df['A'].map(fruit_to_color)

# %%
df
# Out:
#         A   color
# 0   apple     red
# 1  banana  yellow
# 2  cherry     red
# 3   apple     red

# %%
#Mapping Values Using a Series:

import pandas as pd
data = {'A':['apple','banana','cherry','apple']}
df=pd.DataFrame(data)
print(df)
color_series=pd.Series(['red','yellow','red'], index=['apple','banana','cherry'])
df['Color']=df['A'].map(color_series)
print(df)
# Out:
#         A
# 0   apple
# 1  banana
# 2  cherry
# 3   apple
#         A   Color
# 0   apple     red
# 1  banana  yellow
# 2  cherry     red
# 3   apple     red

# %%
#Applying a Function:

import pandas as pd
data = {'Numbers': [1, 2, 3, 4]}
df = pd.DataFrame(data)
def square(x):
  return x ** 2
df['Squared'] = df['Numbers'].map(square)

df
# Out:
#    Numbers  Squared
# 0        1        1
# 1        2        4
# 2        3        9
# 3        4       16
